# %%
import pandas as pd

# %%
cereal_df = pd.read_csv("cereal.csv", index_col='name')
#to read the file we need for this analysis according to the name column

# %%
cereal_df
#to show the data in the that was read
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_df.head()
#to see the first five rows of the data
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
cereal_df.tail()
#to see the last five rows of the data
# Out:
#                     mfr type  calories  protein  fat  sodium  fiber  carbo  \
# name
# Triples               G    C       110        2    1     250    0.0   21.0
# Trix                  G    C       110        1    1     140    0.0   13.0
# Wheat Chex            R    C       100        3    1     230    3.0   17.0
# Wheaties              G    C       100        3    1     200    3.0   17.0
# Wheaties Honey Gold   G    C       110        2    1     200    1.0   16.0
#
#                      sugars  potass  vitamins  shelf  weight  cups     rating
# name
# Triples                   3      60        25      3     1.0  0.75  39.106174
# Trix                     12      25        25      2     1.0  1.00  27.753301
# Wheat Chex                3     115        25      1     1.0  0.67  49.787445
# Wheaties                  3     110        25      1     1.0  1.00  51.592193
# Wheaties Honey Gold       8      60        25      1     1.0  0.75  36.187559

# %%
carbohydrate = cereal_df.sort_values(['carbo'], ascending=False)
#first, assigning the result on the right hand side to a variable
#sorting out the data according to carbohydrates at descending order
carbohydrate = carbohydrate['carbo'].head()
#first, assigning the result on the right hand side to a variable
carbohydrate
#shows the info about the table,that the carbo column has a data type float with 64 bit.
# Out:
# name
# Rice Chex        23.0
# Rice Krispies    22.0
# Corn Chex        22.0
# Kix              21.0
# Crispix          21.0
# Name: carbo, dtype: float64

# %%
carbs = pd.DataFrame(carbohydrate)
#converts data of the carbohydrate to a dataframe

# %%
carbs
#displays it in a tabular format, the name of the cereal to the left and the amount of carbo is in each cereal.
# Out:
#                carbo
# name
# Rice Chex       23.0
# Rice Krispies   22.0
# Corn Chex       22.0
# Kix             21.0
# Crispix         21.0

# %%
carbohydrate.plot( kind='bar')
#shows the carbohydrate in a bar chart diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
carbohydrate.plot( kind='line')
#shows the carbohydrate in a line graph diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
proteins = cereal_df.sort_values(['protein'], ascending=False)
#first, assigning the result on the right hand side to a variable
#sorting out the data according to protein at descending order
proteins = proteins['protein'].head()
#first, assigning the result on the right hand side to a variable
proteins
#shows the info about the table,that the protein has a data type int with 64 bit.
# Out:
# name
# Cheerios          6
# Special K         6
# Quaker Oatmeal    5
# 100% Bran         4
# All-Bran          4
# Name: protein, dtype: int64

# %%
protein = pd.DataFrame(proteins)
#converts data of the protein to a dataframe

# %%
protein
#displays it in a tabular format, the name of the cereal to the left and the amount of protein is in each cereal.
# Out:
#                 protein
# name
# Cheerios              6
# Special K             6
# Quaker Oatmeal        5
# 100% Bran             4
# All-Bran              4

# %%
proteins.plot( kind='bar')
#shows the protein in a bar chart diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
proteins.plot( kind='line')
#shows the protein in a bar chart diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
fats = cereal_df.sort_values(['fat'], ascending=False)
#first, assigning the result on the right hand side to a variable
#sorting out the data according to fat at descending order
fats = fats['fat'].head()
#first, assigning the result on the right hand side to a variable
fats
#shows the info about the table,that the fat column has a data type int with 64 bit.
# Out:
# name
# 100% Natural Bran                    5
# Cracklin' Oat Bran                   3
# Great Grains Pecan                   3
# Muesli Raisins; Peaches; & Pecans    3
# Muesli Raisins; Dates; & Almonds     3
# Name: fat, dtype: int64

# %%
fats = pd.DataFrame(fats)
#converts data of the fat to a dataframe

# %%
fats
#displays it in a tabular format, the name of the cereal to the left and the amount of fat is in each cereal.
# Out:
#                                    fat
# name
# 100% Natural Bran                    5
# Cracklin' Oat Bran                   3
# Great Grains Pecan                   3
# Muesli Raisins; Peaches; & Pecans    3
# Muesli Raisins; Dates; & Almonds     3

# %%
fats.plot( kind='bar')
#shows the fat in a bar chart diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
fats.plot( kind='line')
#shows the fat in a line graph diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
vitamin = cereal_df.sort_values(['vitamins'], ascending=False)
#first, assigning the result on the right hand side to a variable
#sorting out the data according to vitamin at descending order
vitamin = vitamin['vitamins'].head()
#first, assigning the result on the right hand side to a variable
vitamin
#shows the info about the table,that the vitamin column has a data type int with 64 bit.
# Out:
# name
# Just Right Crunchy  Nuggets    100
# Total Whole Grain              100
# Total Corn Flakes              100
# Total Raisin Bran              100
# Product 19                     100
# Name: vitamins, dtype: int64

# %%
vitamin = pd.DataFrame(vitamin)
#converts data of the vitamins to a dataframe

# %%
vitamin
#displays it in a tabular format, the name of the cereal to the left and the amount of vitamins is in each cereal.
# Out:
#                              vitamins
# name
# Just Right Crunchy  Nuggets       100
# Total Whole Grain                 100
# Total Corn Flakes                 100
# Total Raisin Bran                 100
# Product 19                        100

# %%
fats.plot( kind='bar')
#shows the fat in a bar chart diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
fats.plot( kind='line')
#shows the fat in a line graph diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
fibre = cereal_df.sort_values(['fiber'], ascending=False)
#first, assigning the result on the right hand side to a variable
#sorting out the data according to fiber at descending order
fibre = fibre['fiber'].head()
#first, assigning the result on the right hand side to a variable
fibre
#shows the info about the table,that the fiber column has a data type int with 64 bit.
# Out:
# name
# All-Bran with Extra Fiber    14.0
# 100% Bran                    10.0
# All-Bran                      9.0
# Post Nat. Raisin Bran         6.0
# Raisin Bran                   5.0
# Name: fiber, dtype: float64

# %%
fibre = pd.DataFrame(fibre)
#converts data of the fiber to a dataframe

# %%
fibre
#displays it in a tabular format, the name of the cereal to the left and the amount of fiber is in each cereal.
# Out:
#                            fiber
# name
# All-Bran with Extra Fiber   14.0
# 100% Bran                   10.0
# All-Bran                     9.0
# Post Nat. Raisin Bran        6.0
# Raisin Bran                  5.0

# %%
fibre.plot( kind='bar')
#shows the fiber in a bar chart diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
fibre.plot( kind='line')
#shows the fiber in a line graph diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
cereal_df.isnull()
# to displayed all null  values in the table
# Out:
#                              mfr   type  calories  protein    fat  sodium  \
# name
# 100% Bran                  False  False     False    False  False   False
# 100% Natural Bran          False  False     False    False  False   False
# All-Bran                   False  False     False    False  False   False
# All-Bran with Extra Fiber  False  False     False    False  False   False
# Almond Delight             False  False     False    False  False   False
# ...                          ...    ...       ...      ...    ...     ...
# Triples                    False  False     False    False  False   False
# Trix                       False  False     False    False  False   False
# Wheat Chex                 False  False     False    False  False   False
# Wheaties                   False  False     False    False  False   False
# Wheaties Honey Gold        False  False     False    False  False   False
#
# ...

# %%
import numpy as np
# this allows us create null values in the data
cereal_df['rating'].replace(cereal_df['rating'][74], np.nan, inplace= False)
#we are making the rating column of row 74 become null, also we made inplace false so the effect is temporary and it doesn't
#affect the main table
# Out:
# name
# 100% Bran                    68.402973
# 100% Natural Bran            33.983679
# All-Bran                     59.425505
# All-Bran with Extra Fiber    93.704912
# Almond Delight               34.384843
#                                ...
# Triples                      39.106174
# Trix                         27.753301
# Wheat Chex                         NaN
# Wheaties                     51.592193
# Wheaties Honey Gold          36.187559
# Name: rating, Length: 77, dtype: float64

# %%
cereal_df.isnull()
# to displayed all null  values in the table
#here it doesn't display the null because we set the inplace to false so it has no effect on the real table
# Out:
#                              mfr   type  calories  protein    fat  sodium  \
# name
# 100% Bran                  False  False     False    False  False   False
# 100% Natural Bran          False  False     False    False  False   False
# All-Bran                   False  False     False    False  False   False
# All-Bran with Extra Fiber  False  False     False    False  False   False
# Almond Delight             False  False     False    False  False   False
# ...                          ...    ...       ...      ...    ...     ...
# Triples                    False  False     False    False  False   False
# Trix                       False  False     False    False  False   False
# Wheat Chex                 False  False     False    False  False   False
# Wheaties                   False  False     False    False  False   False
# Wheaties Honey Gold        False  False     False    False  False   False
#
# ...

# %%
cereal_df.isnull().sum()
# to displayed all null  values in the table
#here it doesn't display the null because we set the inplace to false so it has no effect on the real table
# Out:
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
cereal_df.describe
#we can get a summary of the distribution of continuous variables
#also be used on a categorical variable to get the count of rows, unique count of categories
#, top category, and freq of top category
# Out:
# <bound method NDFrame.describe of                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_df['minerals'] = cereal_df['sodium'] + cereal_df['potass']
#we created a new column called minerals and add all the separate columns to form one
cereal_df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating  minerals
# name
# ...

# %%
minerals = cereal_df.sort_values(['minerals'], ascending=False)
#first, assigning the result on the right hand side to a variable
#sorting out the data according to minerals at descending order
minerals = minerals['minerals'].head()
#first, assigning the result on the right hand side to a variable
minerals
#shows the info about the table,that the minerals column has a data type int with 64 bit.
# Out:
# name
# All-Bran                     580
# All-Bran with Extra Fiber    470
# Post Nat. Raisin Bran        460
# Raisin Bran                  450
# Fruitful Bran                430
# Name: minerals, dtype: int64

# %%
minerals = pd.DataFrame(minerals)
#converts data of the minerals to a dataframe

# %%
minerals
#displays it in a tabular format, the name of the cereal to the left and the amount of minerals is in each cereal.
# Out:
#                            minerals
# name
# All-Bran                        580
# All-Bran with Extra Fiber       470
# Post Nat. Raisin Bran           460
# Raisin Bran                     450
# Fruitful Bran                   430

# %%
minerals.plot( kind='bar')
#shows the fiber in a bar chart diagram.
# Out:
# <AxesSubplot:xlabel='name'>

# %%
minerals.plot( kind='line')
#shows the minerals in a line graph diagram.
# Out:
# <AxesSubplot:xlabel='name'>
